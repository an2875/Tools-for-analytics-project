# %%
from pandas_datareader import data as web
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt 
from matplotlib.pyplot import figure
# %matplotlib inline

# %%
datafile = 'final_data.csv'
df = pd.read_csv(datafile)
df.rename(columns={'Unnamed: 0': 'Date'}, inplace=True)
df = df[np.isfinite(df['Pct_change'])]
df
# Out:
#            Date  Anticipation   Disgust      Fear       Joy  Negative  \
# 0    2016-06-15      0.006228  0.001465  0.002931  0.001465  0.005251
# 1    2016-06-14      0.008983  0.000876  0.005916  0.003944  0.006792
# 2    2016-06-07      0.010428  0.001259  0.003955  0.001618  0.006832
# 3    2016-06-06      0.005579  0.001064  0.003640  0.003144  0.005720
# 6    2016-06-03      0.009411  0.001520  0.002943  0.003848  0.007567
# 7    2016-06-02      0.010932  0.002106  0.004639  0.006168  0.010982
# 8    2016-06-01      0.010272  0.002003  0.004092  0.004518  0.010400
# 9    2016-05-31      0.009897  0.001840  0.005004  0.004268  0.007211
# 13   2016-05-27      0.012429  0.001847  0.003764  0.004084  0.007848
# 14   2016-05-26      0.014248  0.001236  0.003503  0.007301  0.007890
# 15   2016-05-25      0.010031  0.001507  0.003013  0.006522  0.008128
# 16   2016-05-24      0.007626  0.001318  0.003613  0.003613  0.006109
# ...

# %%
def line_chart(x,y):
    line_ = df.plot(x='Date', y= 'Disgust',figsize=(10, 6),color="r")

# %%
df.plot(x='Date', y= 'Disgust',figsize=(10, 6),color="r")  
plt.show()

# %%
df.plot(x='Date', y= 'Fear',figsize=(10, 6),color="r")  
plt.show()

# %%
df.plot(x='Date', y= 'Negative',figsize=(10, 6),color="r")  
plt.show()

# %%
df.plot(x='Date', y= 'Sadness',figsize=(10, 6),color="r")  
plt.show()

# %%
df.plot(x='Date', y= 'Anticipation',figsize=(10, 6),color="b")  
plt.show()

# %%
df.plot(x='Date', y= 'Joy',figsize=(10, 6),color="b")  
plt.show()

# %%
df.plot(x='Date', y= 'Positive',figsize=(10, 6),color="b")  
plt.show()

# %%
df.plot(x='Date', y= 'Surprise',figsize=(10, 6),color="b")  
plt.show()

# %%
df.plot(x='Date', y= 'Trust',figsize=(10, 6),color="b")  
plt.show()

# %%
plt.scatter(df.Pct_change, df.Negative,color="r")  
plt.show()
